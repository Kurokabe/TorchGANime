# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from datasets import load_dataset, Image

# %%
dataset = load_dataset("imagefolder", data_dir="/TorchGANime/data/kny/images/01/", drop_labels=True).cast_column("image", Image())
# Out:
# Resolving data files: 100%|██████████| 6000/6000 [00:00<00:00, 54287.35it/s]
# Resolving data files: 100%|██████████| 809/809 [00:00<00:00, 175640.14it/s]
# Using custom data configuration default-322ddf23c9c5e362
# Found cached dataset imagefolder (/root/.cache/huggingface/datasets/imagefolder/default-322ddf23c9c5e362/0.0.0/37fbb85cc714a338bea574ac6c7d0b5be5aff46c1862c1989b20e0771199e93f)
# 100%|██████████| 2/2 [00:00<00:00, 33.84it/s]

# %%
ds = load_dataset("Kurokabe/Kimetsu-no-Yaiba-Image-Dataset-01")
# Out:
# Downloading readme: 100%|██████████| 458/458 [00:00<00:00, 225kB/s]
# Using custom data configuration Kurokabe--Kimetsu-no-Yaiba-Image-Dataset-01-65e9ebf56b611556
# Downloading and preparing dataset None/None to /root/.cache/huggingface/datasets/Kurokabe___parquet/Kurokabe--Kimetsu-no-Yaiba-Image-Dataset-01-65e9ebf56b611556/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec...
# Downloading data: 100%|██████████| 399M/399M [00:09<00:00, 40.4MB/s]
# Downloading data: 100%|██████████| 414M/414M [00:10<00:00, 39.2MB/s]
# Downloading data: 100%|██████████| 395M/395M [00:10<00:00, 37.3MB/s]
# Downloading data: 100%|██████████| 360M/360M [00:09<00:00, 39.9MB/s]
# Downloading data: 100%|██████████| 361M/361M [00:09<00:00, 37.0MB/s]
# Downloading data: 100%|██████████| 207M/207M [00:05<00:00, 36.1MB/s]]
# Downloading data files: 100%|██████████| 2/2 [01:06<00:00, 33.24s/it]
# Extracting data files #1: 100%|██████████| 1/1 [00:00<00:00, 272.18obj/s]
# Extracting data files #0: 100%|██████████| 1/1 [00:00<00:00, 58.54obj/s]
# Dataset parquet downloaded and prepared to /root/.cache/huggingface/datasets/Kurokabe___parquet/Kurokabe--Kimetsu-no-Yaiba-Image-Dataset-01-65e9ebf56b611556/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec. Subsequent calls will reuse this data.
# 100%|██████████| 2/2 [00:00<00:00, 77.02it/s]

# %%
ds["validation"][50]["image"]
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=848x480>
